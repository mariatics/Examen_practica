# %%
class conet:
    def __init__(self, alumno):
        self.alumno =alumno
    def usuario(self):
          print("este es el nombre del alumno:", self.alumno)
    def grado(self):
            print("esta activo")
    def grupo(self):
          print("esta en un grupo")

# %%
juan = conet ("juan")
juan.grado()
juan.grupo()
juan.usuario()
# Out:
# esta activo
# esta en un grupo
# este es el nombre del alumno: juan

# %%
class estudiante (conet):
    def usuario (self):
      print("el nombre del alumno es",self.alumno)
    def llora(self):
       print("todo tonto llora")
    def grado(self):
       print("el grado del alumno es",)

# %%
coco = estudiante("coco")
coco.llora()
coco.usuario()
coco.grupo()
# Out:
# todo tonto llora
# el nombre del alumno es coco
# esta en un grupo
